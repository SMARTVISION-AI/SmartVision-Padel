# %% [markdown]
# # Codigo Main

# %%
# !pip install opencv-python matplotlib numpy

# %%
import numpy as np
import sys
import cv2
import matplotlib.pyplot as plt

# Añadir la ruta donde se encuentra homography.py al sistema de rutas
sys.path.append('.')
from homography import apply_homography

# %%
def main():
    image_path = '../utils/cancha-base.png'

    # Aplicar la homografía y muestra imagen
    img_out = apply_homography(image_path)

main()
